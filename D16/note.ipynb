# %% [markdown]
# Data Handling and Cleaning
# - Cover the parts that remain from Data Cleaning
# - Revise Data Cleaning
# - Just observe how to implement distributions in python, revise distributions a little
# - Tour to Git
# - SQL introduction
#
# - Learn some data analytics skills

# %% [markdown]
# Tomorrow:
# - Data Storytelling with EDA
# - Python Libraries: Plotly and Seaborn
# - Intro to PowerBI
# - Mini Project - Do the first three steps and EDA properly
