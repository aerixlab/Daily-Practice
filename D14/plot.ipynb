# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
# plot a line for the question y=x
#
x = 2*x
y = 

plt.plot(x,y)
# Out:
#   Cell In[3], line 3
#     x =
#        ^
# SyntaxError: invalid syntax

# %%
import matplotlib.pyplot as plt

x = np.linspace(-50,50,50)
e = 2* ((x+3)**2) + 3
plt.plot(x,e)
plt.axhline(0, linewidth=0.5)
plt.axvline(0, linewidth=0.5)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
arr=np.array([12,2,3,43,1])
arr
# Out:
# array([12,  2,  3, 43,  1])

# %%
darr = arr*2

# %%
darr
# Out:
# array([24,  4,  6, 86,  2])

# %%
arr2 = np.array([1,3,4,4,2])
sarr = arr@darr

# %%
sarr
# Out:
# np.int64(4014)

# %%
print(sarr)
# Out:
# 4014
