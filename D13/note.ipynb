# %% [markdown]
# LINEAR ALGEBRA
# - Things about Linear Algebra
# - Scalers
# - Vectors
# - Matrices
# - Dot product
# - Matrix product
#
# Why we have to study this?
# We do a lot of calculation
# We deal a lot of indices, matrices, dimensions
# To help build AI model
#
# So far, we have dealt with a lot of data
# - Data most of the operations that we did, are based on linear algebra?
# - Lists, arrays, dictionary
# - Linear structures
# - pandas

# %%
list2 = [3,4,5,'Sha', 4.5, [3, ['a','b'],5]]
list2[5][1][0]
# Out:
# 'a'

# %%
vector1 = [3,4,10]
vector2 = [2,4,10]

# %%
matrix2 = [vector1,vector2]
# [2,4,10] as a result
matrix2 #2 as a result
# Out:
# [[3, 4, 10], [2, 4, 10]]

# %%
type(matrix2)
# Out:
# list

# %%
matrix2.index()
matrix2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 matrix2.index()
#       2 matrix2
#
# TypeError: index expected at least 1 argument, got 0

# %%
sum(vector1)
# Out:
# 17
